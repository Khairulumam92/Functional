# %% [markdown]
# # Soal Latihan Ujian Akhir Praktikum (UAP)
# ## Pemrograman Fungsional - Modul 1-6
#
# ---
#
# ## 📋 KETENTUAN PENGERJAAN
#
# 1. **Waktu pengerjaan: 70 menit**
# 2. **Wajib menggunakan paradigma pemrograman fungsional**
# 3. **Implementasi wajib menerapkan konsep-konsep:**
#    - Pure Function
#    - Generator Expression
#    - List Comprehension
#    - Filter
#    - Map
#    - Reduce
#    - Lambda
#    - Closure
#    - Visualisasi (matplotlib)
# 4. **Pastikan library `functools` dan `matplotlib` telah terinstal**
# 5. **Semua fungsi harus pure functions (no side effects)**
# 6. **Gunakan immutable data structures**
# 7. **UAP akan dilaksanakan secara LIVE CODING**
#
# ---

# %% [markdown]
# # SOAL: Analisis Data Penjualan Restoran
#
# ## 📊 Studi Kasus
# Sebuah restoran ingin menganalisis data penjualan mereka untuk evaluasi performa dan pengambilan keputusan bisnis. Data penjualan diberikan dalam bentuk list of dictionaries.
#
# ## 📦 Data yang Diberikan
#
# Data penjualan restoran selama beberapa bulan dengan informasi:
# - ID transaksi
# - Nama menu
# - Kategori menu (Makanan, Minuman, Dessert)
# - Harga per item
# - Jumlah terjual
# - Bulan transaksi
# - Rating pelanggan (1-5)

# %%
# Data penjualan restoran
data_penjualan = [
    {"id": 1, "menu": "Nasi Goreng", "kategori": "Makanan", "harga": 25000, "jumlah": 150, "bulan": "Januari", "rating": 4.5},
    {"id": 2, "menu": "Mie Ayam", "kategori": "Makanan", "harga": 20000, "jumlah": 120, "bulan": "Januari", "rating": 4.3},
    {"id": 3, "menu": "Es Teh", "kategori": "Minuman", "harga": 8000, "jumlah": 200, "bulan": "Januari", "rating": 4.2},
    {"id": 4, "menu": "Es Jeruk", "kategori": "Minuman", "harga": 10000, "jumlah": 180, "bulan": "Januari", "rating": 4.4},
    {"id": 5, "menu": "Pudding", "kategori": "Dessert", "harga": 15000, "jumlah": 80, "bulan": "Januari", "rating": 4.6},
    {"id": 6, "menu": "Nasi Goreng", "kategori": "Makanan", "harga": 25000, "jumlah": 165, "bulan": "Februari", "rating": 4.6},
    {"id": 7, "menu": "Mie Ayam", "kategori": "Makanan", "harga": 20000, "jumlah": 135, "bulan": "Februari", "rating": 4.4},
    {"id": 8, "menu": "Es Teh", "kategori": "Minuman", "harga": 8000, "jumlah": 220, "bulan": "Februari", "rating": 4.3},
    {"id": 9, "menu": "Es Jeruk", "kategori": "Minuman", "harga": 10000, "jumlah": 190, "bulan": "Februari", "rating": 4.5},
    {"id": 10, "menu": "Pudding", "kategori": "Dessert", "harga": 15000, "jumlah": 90, "bulan": "Februari", "rating": 4.7},
    {"id": 11, "menu": "Nasi Goreng", "kategori": "Makanan", "harga": 25000, "jumlah": 180, "bulan": "Maret", "rating": 4.7},
    {"id": 12, "menu": "Mie Ayam", "kategori": "Makanan", "harga": 20000, "jumlah": 140, "bulan": "Maret", "rating": 4.5},
    {"id": 13, "menu": "Es Teh", "kategori": "Minuman", "harga": 8000, "jumlah": 240, "bulan": "Maret", "rating": 4.4},
    {"id": 14, "menu": "Es Jeruk", "kategori": "Minuman", "harga": 10000, "jumlah": 200, "bulan": "Maret", "rating": 4.6},
    {"id": 15, "menu": "Pudding", "kategori": "Dessert", "harga": 15000, "jumlah": 100, "bulan": "Maret", "rating": 4.8},
    {"id": 16, "menu": "Nasi Goreng", "kategori": "Makanan", "harga": 25000, "jumlah": 170, "bulan": "April", "rating": 4.6},
    {"id": 17, "menu": "Mie Ayam", "kategori": "Makanan", "harga": 20000, "jumlah": 130, "bulan": "April", "rating": 4.4},
    {"id": 18, "menu": "Es Teh", "kategori": "Minuman", "harga": 8000, "jumlah": 210, "bulan": "April", "rating": 4.3},
    {"id": 19, "menu": "Es Jeruk", "kategori": "Minuman", "harga": 10000, "jumlah": 185, "bulan": "April", "rating": 4.5},
    {"id": 20, "menu": "Pudding", "kategori": "Dessert", "harga": 15000, "jumlah": 85, "bulan": "April", "rating": 4.6}
]

print(f"Total data penjualan: {len(data_penjualan)} transaksi")
print(f"Periode: Januari - April")
print(f"Jumlah menu unik: {len(set(item['menu'] for item in data_penjualan))}")

# %% [markdown]
# ## 📝 TUGAS YANG HARUS DIKERJAKAN
#
# ### **BAGIAN 1: Pure Functions untuk Data Processing** (35 menit)
#
# #### **1. Hitung Total Revenue per Item** (5 menit)
# Buat **pure function** `hitung_total_revenue(item)` yang menerima satu item penjualan dan mengembalikan total revenue (harga × jumlah).
#
# **Contoh:**
# ```python
# item = {"harga": 25000, "jumlah": 150}
# total = hitung_total_revenue(item)  # 3750000
# ```
#
# #### **2. Tambahkan Field Total Revenue** (5 menit)
# Buat **pure function** `tambah_total_revenue(data)` yang menggunakan **map** dan **lambda** untuk menambahkan field `total_revenue` ke setiap item dalam data.
#
# **Ketentuan:**
# - Gunakan `map` dengan lambda
# - Buat dictionary baru untuk setiap item (immutable update)
# - Return list baru, jangan modifikasi data asli
#
# #### **3. Filter Data Berdasarkan Kategori** (5 menit)
# Buat **pure function** `filter_kategori(data, kategori)` yang menggunakan **filter** dan **lambda** untuk memfilter data berdasarkan kategori.
#
# **Contoh:**
# ```python
# data_makanan = filter_kategori(data_penjualan, "Makanan")
# ```
#
# #### **4. Hitung Total Omset Keseluruhan** (5 menit)
# Buat **pure function** `hitung_total_omset(data)` yang menggunakan **reduce** dari `functools` untuk menghitung total omset semua penjualan.
#
# **Ketentuan:**
# - Import `reduce` dari `functools`
# - Gunakan lambda dalam reduce
# - Return total omset (integer)
#
# #### **5. Kelompokkan Data per Bulan** (5 menit)
# Buat **pure function** `kelompokkan_per_bulan(data)` yang menggunakan **list comprehension** untuk mengelompokkan data per bulan dan menghitung total omset per bulan.
#
# **Output yang diharapkan:**
# ```python
# {
#     "Januari": 12345000,
#     "Februari": 13500000,
#     "Maret": 14500000,
#     "April": 13200000
# }
# ```
#
# #### **6. Factory Function dengan Closure** (5 menit)
# Buat **factory function dengan closure** `buat_filter_harga(min_harga, max_harga)` yang mengembalikan fungsi filter untuk memfilter produk berdasarkan range harga.
#
# **Contoh penggunaan:**
# ```python
# filter_murah = buat_filter_harga(0, 15000)
# data_murah = list(filter(filter_murah, data_penjualan))
# ```
#
# #### **7. Generator Expression** (5 menit)
# Buat **generator expression** untuk menghasilkan total revenue per item tanpa menyimpan semua data di memory.
#
# **Ketentuan:**
# - Gunakan generator expression (bukan list comprehension)
# - Iterasi melalui data dan hitung total revenue
# - Tampilkan 5 item pertama menggunakan `next()` atau loop
#
# ### **BAGIAN 2: Analisis Data dengan List Comprehension** (10 menit)
#
# #### **8. Rata-rata Rating per Kategori** (5 menit)
# Buat **pure function** `rata_rata_rating_per_kategori(data)` yang menggunakan **list comprehension** dan **reduce** untuk menghitung rata-rata rating per kategori.
#
# **Output yang diharapkan:**
# ```python
# {
#     "Makanan": 4.5,
#     "Minuman": 4.4,
#     "Dessert": 4.7
# }
# ```
#
# #### **9. Menu Terlaris per Bulan** (5 menit)
# Buat **pure function** `menu_terlaris_per_bulan(data)` yang menggunakan **list comprehension** untuk menemukan menu dengan jumlah terjual terbanyak per bulan.
#
# **Output yang diharapkan:**
# ```python
# {
#     "Januari": ("Es Teh", 200),
#     "Februari": ("Es Teh", 220),
#     "Maret": ("Es Teh", 240),
#     "April": ("Es Teh", 210)
# }
# ```
#
# ### **BAGIAN 3: Visualisasi Data** (25 menit)
#
# #### **10. Buat Visualisasi dengan Matplotlib** (25 menit)
# Buat visualisasi menggunakan **matplotlib** dengan 4 subplot dalam satu figure:
#
# **Subplot 1 - Bar Chart:** Total omset per kategori produk
# - Sumbu X: Kategori (Makanan, Minuman, Dessert)
# - Sumbu Y: Total omset (dalam juta rupiah)
# - Warna berbeda untuk setiap kategori
# - Tambahkan label nilai di atas setiap bar
#
# **Subplot 2 - Pie Chart:** Distribusi penjualan per bulan (dalam persentase)
# - Label: Nama bulan
# - Format persentase dengan 1 desimal
# - Warna berbeda untuk setiap bulan
# - Start angle: 90 derajat
#
# **Subplot 3 - Line Chart:** Trend omset per bulan
# - Sumbu X: Bulan (Januari, Februari, Maret, April)
# - Sumbu Y: Total omset
# - Marker: 'o'
# - Line width: 2
# - Grid: True
#
# **Subplot 4 - Scatter Plot:** Hubungan antara harga vs jumlah terjual
# - Sumbu X: Harga produk
# - Sumbu Y: Jumlah terjual
# - Warna berbeda untuk setiap kategori
# - Alpha: 0.6
# - Size: berdasarkan rating (rating × 50)
# - Legend: Tampilkan kategori
#
# **Ketentuan Visualisasi:**
# - Figure size: (16, 10)
# - Layout: 2x2 subplot
# - Title untuk setiap subplot
# - Label untuk sumbu X dan Y
# - Grid untuk line chart dan scatter plot
# - Format angka dengan pemisah ribuan (misal: 1.000.000)
# - Overall title: "Analisis Data Penjualan Restoran"
# - Tight layout
#
# ## ✅ OUTPUT YANG DIHARAPKAN
#
# 1. Data dengan field `total_revenue` yang ditambahkan
# 2. Total omset keseluruhan
# 3. Data penjualan per bulan (dictionary)
# 4. Rata-rata rating per kategori
# 5. Menu terlaris per bulan
# 6. Visualisasi 4 subplot seperti yang diminta
#
# ## 📌 PETUNJUK PENTING
#
# 1. **Semua fungsi harus pure functions** - tidak ada side effects, tidak ada print/input di dalam fungsi
# 2. **Gunakan immutable update** - selalu buat data baru, jangan modifikasi data asli
# 3. **Kombinasikan semua teknik** - list comprehension, map, filter, reduce, lambda, closure, generator expression
# 4. **Visualisasi harus informatif** - title, label, legend, grid, format angka
# 5. **Waktu terbatas** - fokus pada bagian yang paling penting terlebih dahulu
# 6. **Test setiap fungsi** - pastikan fungsi bekerja dengan benar sebelum melanjutkan
#
# ## 🎯 SKOR PENILAIAN
#
# - **Bagian 1 (Pure Functions)**: 40 poin
# - **Bagian 2 (Analisis Data)**: 20 poin
# - **Bagian 3 (Visualisasi)**: 40 poin
# - **Total**: 100 poin
#
# **Selamat mengerjakan! Semoga sukses di UAP! 🚀**

# %%
# Import library yang diperlukan
from functools import reduce
import matplotlib.pyplot as plt

# Data penjualan restoran
data_penjualan = [
    {"id": 1, "menu": "Nasi Goreng", "kategori": "Makanan", "harga": 25000, "jumlah": 150, "bulan": "Januari", "rating": 4.5},
    {"id": 2, "menu": "Mie Ayam", "kategori": "Makanan", "harga": 20000, "jumlah": 120, "bulan": "Januari", "rating": 4.3},
    {"id": 3, "menu": "Es Teh", "kategori": "Minuman", "harga": 8000, "jumlah": 200, "bulan": "Januari", "rating": 4.2},
    {"id": 4, "menu": "Es Jeruk", "kategori": "Minuman", "harga": 10000, "jumlah": 180, "bulan": "Januari", "rating": 4.4},
    {"id": 5, "menu": "Pudding", "kategori": "Dessert", "harga": 15000, "jumlah": 80, "bulan": "Januari", "rating": 4.6},
    {"id": 6, "menu": "Nasi Goreng", "kategori": "Makanan", "harga": 25000, "jumlah": 165, "bulan": "Februari", "rating": 4.6},
    {"id": 7, "menu": "Mie Ayam", "kategori": "Makanan", "harga": 20000, "jumlah": 135, "bulan": "Februari", "rating": 4.4},
    {"id": 8, "menu": "Es Teh", "kategori": "Minuman", "harga": 8000, "jumlah": 220, "bulan": "Februari", "rating": 4.3},
    {"id": 9, "menu": "Es Jeruk", "kategori": "Minuman", "harga": 10000, "jumlah": 190, "bulan": "Februari", "rating": 4.5},
    {"id": 10, "menu": "Pudding", "kategori": "Dessert", "harga": 15000, "jumlah": 90, "bulan": "Februari", "rating": 4.7},
    {"id": 11, "menu": "Nasi Goreng", "kategori": "Makanan", "harga": 25000, "jumlah": 180, "bulan": "Maret", "rating": 4.7},
    {"id": 12, "menu": "Mie Ayam", "kategori": "Makanan", "harga": 20000, "jumlah": 140, "bulan": "Maret", "rating": 4.5},
    {"id": 13, "menu": "Es Teh", "kategori": "Minuman", "harga": 8000, "jumlah": 240, "bulan": "Maret", "rating": 4.4},
    {"id": 14, "menu": "Es Jeruk", "kategori": "Minuman", "harga": 10000, "jumlah": 200, "bulan": "Maret", "rating": 4.6},
    {"id": 15, "menu": "Pudding", "kategori": "Dessert", "harga": 15000, "jumlah": 100, "bulan": "Maret", "rating": 4.8},
    {"id": 16, "menu": "Nasi Goreng", "kategori": "Makanan", "harga": 25000, "jumlah": 170, "bulan": "April", "rating": 4.6},
    {"id": 17, "menu": "Mie Ayam", "kategori": "Makanan", "harga": 20000, "jumlah": 130, "bulan": "April", "rating": 4.4},
    {"id": 18, "menu": "Es Teh", "kategori": "Minuman", "harga": 8000, "jumlah": 210, "bulan": "April", "rating": 4.3},
    {"id": 19, "menu": "Es Jeruk", "kategori": "Minuman", "harga": 10000, "jumlah": 185, "bulan": "April", "rating": 4.5},
    {"id": 20, "menu": "Pudding", "kategori": "Dessert", "harga": 15000, "jumlah": 85, "bulan": "April", "rating": 4.6}
]

# ============================================
# BAGIAN 1: Pure Functions untuk Data Processing
# ============================================

# Tulis jawaban Anda di sini

# %% [markdown]
# ---
#
# ## 📝 Catatan
#
# **Kunci Jawaban tersedia di file terpisah:** `Kunci_Jawaban_UAP_Final.ipynb`
#
# **Tips Pengerjaan:**
# 1. Baca soal dengan teliti
# 2. Buat fungsi satu per satu dan test setiap fungsi
# 3. Pastikan semua fungsi adalah pure functions
# 4. Gunakan immutable update untuk dictionary
# 5. Fokus pada bagian yang paling penting terlebih dahulu
# 6. Visualisasi bisa dibuat setelah semua fungsi selesai
#
# **Selamat berlatih! Semoga sukses di UAP! 🚀**
