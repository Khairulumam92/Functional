# %% [markdown]
# # Soal Latihan Ujian Akhir Praktikum (UAP)
# ## Pemrograman Fungsional - Modul 1-6
#
# ---
#
# **Ketentuan:**
# 1. Waktu pengerjaan: 70 menit
# 2. Wajib menggunakan paradigma pemrograman fungsional
# 3. Implementasi wajib menerapkan: Pure Function, Generator Expression, List Comprehension, Filter, Map, Reduce, Lambda, Closure, dan Visualisasi
# 4. Pastikan library `functools` dan `matplotlib` telah terinstal
# 5. Semua fungsi harus pure functions (no side effects)
# 6. Gunakan immutable data structures
#
# ---

# %% [markdown]
# # SOAL 1: Analisis Data Penjualan Toko Elektronik
#
# ## Studi Kasus
# Sebuah toko elektronik ingin menganalisis data penjualan mereka. Data penjualan diberikan dalam bentuk list of dictionaries.
#
# ## Data yang Diberikan
# ```python
# data_penjualan = [
#     {"id": 1, "produk": "Laptop", "kategori": "Komputer", "harga": 12000000, "jumlah": 3, "bulan": "Januari"},
#     {"id": 2, "produk": "Mouse", "kategori": "Aksesoris", "harga": 150000, "jumlah": 25, "bulan": "Januari"},
#     {"id": 3, "produk": "Keyboard", "kategori": "Aksesoris", "harga": 500000, "jumlah": 15, "bulan": "Februari"},
#     {"id": 4, "produk": "Monitor", "kategori": "Komputer", "harga": 3000000, "jumlah": 8, "bulan": "Februari"},
#     {"id": 5, "produk": "Headset", "kategori": "Aksesoris", "harga": 800000, "jumlah": 20, "bulan": "Maret"},
#     {"id": 6, "produk": "Printer", "kategori": "Perangkat", "harga": 2500000, "jumlah": 5, "bulan": "Maret"},
#     {"id": 7, "produk": "Webcam", "kategori": "Aksesoris", "harga": 600000, "jumlah": 12, "bulan": "April"},
#     {"id": 8, "produk": "Tablet", "kategori": "Komputer", "harga": 5000000, "jumlah": 6, "bulan": "April"},
#     {"id": 9, "produk": "Speaker", "kategori": "Aksesoris", "harga": 1200000, "jumlah": 18, "bulan": "Mei"},
#     {"id": 10, "produk": "SSD", "kategori": "Komponen", "harga": 1500000, "jumlah": 30, "bulan": "Mei"}
# ]
# ```
#
# ## Tugas yang Harus Dikerjakan
#
# ### Bagian 1: Pure Functions untuk Data Processing (30 menit)
#
# 1. **Buat pure function `hitung_total_penjualan(item)`** yang menerima satu item penjualan dan mengembalikan total penjualan (harga × jumlah).
#
# 2. **Buat pure function `tambah_total_penjualan(data)`** yang menggunakan **map** untuk menambahkan field `total_penjualan` ke setiap item dalam data.
#
# 3. **Buat pure function `filter_kategori(data, kategori)`** yang menggunakan **filter** dan **lambda** untuk memfilter data berdasarkan kategori.
#
# 4. **Buat pure function `hitung_total_omset(data)`** yang menggunakan **reduce** dari functools untuk menghitung total omset semua penjualan.
#
# 5. **Buat pure function `kelompokkan_per_bulan(data)`** yang menggunakan **list comprehension** untuk mengelompokkan data per bulan dan menghitung total omset per bulan.
#
# 6. **Buat factory function dengan closure `buat_filter_harga(min_harga, max_harga)`** yang mengembalikan fungsi filter untuk memfilter produk berdasarkan range harga.
#
# 7. **Buat generator expression** untuk menghasilkan total penjualan per item tanpa menyimpan semua data di memory.
#
# ### Bagian 2: Visualisasi Data (40 menit)
#
# 8. **Buat visualisasi menggunakan matplotlib** dengan ketentuan:
#    - **Subplot 1 (Bar Chart)**: Total omset per kategori produk
#    - **Subplot 2 (Pie Chart)**: Distribusi penjualan per bulan (dalam persentase)
#    - **Subplot 3 (Line Chart)**: Trend omset per bulan
#    - **Subplot 4 (Scatter Plot)**: Hubungan antara harga produk vs jumlah terjual
#
#    **Ketentuan Visualisasi:**
#    - Gunakan figure size (14, 10)
#    - Setiap subplot harus memiliki title, label, dan grid
#    - Gunakan warna yang berbeda untuk setiap kategori/bulan
#    - Format angka dengan pemisah ribuan (misal: 1.000.000)
#
# ## Output yang Diharapkan
#
# 1. Data dengan field `total_penjualan` yang ditambahkan
# 2. Total omset keseluruhan
# 3. Data penjualan per bulan
# 4. Visualisasi 4 subplot seperti yang diminta
#
# ## Petunjuk
# - Semua fungsi harus pure (tidak ada side effects)
# - Gunakan immutable update untuk dictionary
# - Kombinasikan list comprehension, map, filter, reduce, lambda, dan closure
# - Pastikan visualisasi menggunakan data yang sudah diproses dengan functional approach

# %%
# Data yang diberikan
data_penjualan = [
    {"id": 1, "produk": "Laptop", "kategori": "Komputer", "harga": 12000000, "jumlah": 3, "bulan": "Januari"},
    {"id": 2, "produk": "Mouse", "kategori": "Aksesoris", "harga": 150000, "jumlah": 25, "bulan": "Januari"},
    {"id": 3, "produk": "Keyboard", "kategori": "Aksesoris", "harga": 500000, "jumlah": 15, "bulan": "Februari"},
    {"id": 4, "produk": "Monitor", "kategori": "Komputer", "harga": 3000000, "jumlah": 8, "bulan": "Februari"},
    {"id": 5, "produk": "Headset", "kategori": "Aksesoris", "harga": 800000, "jumlah": 20, "bulan": "Maret"},
    {"id": 6, "produk": "Printer", "kategori": "Perangkat", "harga": 2500000, "jumlah": 5, "bulan": "Maret"},
    {"id": 7, "produk": "Webcam", "kategori": "Aksesoris", "harga": 600000, "jumlah": 12, "bulan": "April"},
    {"id": 8, "produk": "Tablet", "kategori": "Komputer", "harga": 5000000, "jumlah": 6, "bulan": "April"},
    {"id": 9, "produk": "Speaker", "kategori": "Aksesoris", "harga": 1200000, "jumlah": 18, "bulan": "Mei"},
    {"id": 10, "produk": "SSD", "kategori": "Komponen", "harga": 1500000, "jumlah": 30, "bulan": "Mei"}
]

# Tulis jawaban Anda di sini

# %% [markdown]
# ---
#
# # SOAL 2: Analisis Data Nilai Mahasiswa
#
# ## Studi Kasus
# Sebuah program studi ingin menganalisis data nilai mahasiswa untuk evaluasi pembelajaran.
#
# ## Data yang Diberikan
# ```python
# data_mahasiswa = [
#     {"nim": "2021001", "nama": "Ahmad", "matkul": "Pemrograman", "nilai": 85, "sks": 3, "semester": 1},
#     {"nim": "2021001", "nama": "Ahmad", "matkul": "Basis Data", "nilai": 78, "sks": 3, "semester": 1},
#     {"nim": "2021002", "nama": "Budi", "matkul": "Pemrograman", "nilai": 92, "sks": 3, "semester": 1},
#     {"nim": "2021002", "nama": "Budi", "matkul": "Basis Data", "nilai": 88, "sks": 3, "semester": 1},
#     {"nim": "2021003", "nama": "Citra", "matkul": "Pemrograman", "nilai": 75, "sks": 3, "semester": 1},
#     {"nim": "2021003", "nama": "Citra", "matkul": "Algoritma", "nilai": 80, "sks": 2, "semester": 2},
#     {"nim": "2021004", "nama": "Dedi", "matkul": "Pemrograman", "nilai": 90, "sks": 3, "semester": 1},
#     {"nim": "2021004", "nama": "Dedi", "matkul": "Basis Data", "nilai": 85, "sks": 3, "semester": 1},
#     {"nim": "2021005", "nama": "Eka", "matkul": "Algoritma", "nilai": 88, "sks": 2, "semester": 2},
#     {"nim": "2021005", "nama": "Eka", "matkul": "Pemrograman", "nilai": 95, "sks": 3, "semester": 1}
# ]
# ```
#
# ## Tugas yang Harus Dikerjakan
#
# ### Bagian 1: Pure Functions untuk Data Processing (25 menit)
#
# 1. **Buat pure function `hitung_bobot_nilai(nilai)`** yang mengkonversi nilai angka menjadi bobot:
#    - A (85-100): 4.0
#    - B (70-84): 3.0
#    - C (55-69): 2.0
#    - D (40-54): 1.0
#    - E (<40): 0.0
#
# 2. **Buat pure function `tambah_bobot_dan_ipk(data)`** yang menggunakan **map** dan **lambda** untuk menambahkan field `bobot` dan `ipk` (bobot × sks) ke setiap item.
#
# 3. **Buat pure function `hitung_ipk_per_mahasiswa(data)`** yang menggunakan **list comprehension** dan **reduce** untuk menghitung IPK total setiap mahasiswa (total bobot × sks / total sks).
#
# 4. **Buat pure function `filter_nilai_minimal(data, nilai_min)`** yang menggunakan **filter** dan **lambda** untuk memfilter mahasiswa dengan nilai >= nilai_min.
#
# 5. **Buat factory function dengan closure `buat_kategori_filter(kategori)`** yang mengembalikan fungsi untuk memfilter berdasarkan kategori nilai (A, B, C, D, E).
#
# 6. **Buat generator expression** untuk menghasilkan IPK per mahasiswa tanpa menyimpan semua data di memory.
#
# 7. **Buat pure function `statistik_per_matkul(data)`** yang menggunakan **list comprehension** dan **reduce** untuk menghitung rata-rata nilai per mata kuliah.
#
# ### Bagian 2: Visualisasi Data (45 menit)
#
# 8. **Buat visualisasi menggunakan matplotlib** dengan ketentuan:
#    - **Subplot 1 (Bar Chart)**: Rata-rata nilai per mata kuliah
#    - **Subplot 2 (Horizontal Bar Chart)**: IPK per mahasiswa (urutkan dari tertinggi)
#    - **Subplot 3 (Pie Chart)**: Distribusi kategori nilai (A, B, C, D, E) dalam persentase
#    - **Subplot 4 (Box Plot)**: Distribusi nilai per semester
#
#    **Ketentuan Visualisasi:**
#    - Gunakan figure size (16, 10)
#    - Setiap subplot harus memiliki title, label, dan styling yang jelas
#    - Gunakan warna yang berbeda untuk setiap kategori
#    - Tambahkan anotasi pada chart yang relevan
#
# ## Output yang Diharapkan
#
# 1. Data dengan field `bobot` dan `ipk` per item
# 2. IPK per mahasiswa
# 3. Statistik per mata kuliah
# 4. Visualisasi 4 subplot seperti yang diminta
#
# ## Petunjuk
# - Gunakan semua teknik functional programming yang telah dipelajari
# - Pastikan semua fungsi adalah pure functions
# - Gunakan generator expression untuk data yang besar
# - Visualisasi harus menggunakan data yang sudah diproses dengan functional approach

# %%
# Data yang diberikan
data_mahasiswa = [
    {"nim": "2021001", "nama": "Ahmad", "matkul": "Pemrograman", "nilai": 85, "sks": 3, "semester": 1},
    {"nim": "2021001", "nama": "Ahmad", "matkul": "Basis Data", "nilai": 78, "sks": 3, "semester": 1},
    {"nim": "2021002", "nama": "Budi", "matkul": "Pemrograman", "nilai": 92, "sks": 3, "semester": 1},
    {"nim": "2021002", "nama": "Budi", "matkul": "Basis Data", "nilai": 88, "sks": 3, "semester": 1},
    {"nim": "2021003", "nama": "Citra", "matkul": "Pemrograman", "nilai": 75, "sks": 3, "semester": 1},
    {"nim": "2021003", "nama": "Citra", "matkul": "Algoritma", "nilai": 80, "sks": 2, "semester": 2},
    {"nim": "2021004", "nama": "Dedi", "matkul": "Pemrograman", "nilai": 90, "sks": 3, "semester": 1},
    {"nim": "2021004", "nama": "Dedi", "matkul": "Basis Data", "nilai": 85, "sks": 3, "semester": 1},
    {"nim": "2021005", "nama": "Eka", "matkul": "Algoritma", "nilai": 88, "sks": 2, "semester": 2},
    {"nim": "2021005", "nama": "Eka", "matkul": "Pemrograman", "nilai": 95, "sks": 3, "semester": 1}
]

# Tulis jawaban Anda di sini

# %% [markdown]
# ---
#
# # SOAL 3: Analisis Data Produk E-Commerce (BONUS - Jika Ada Waktu)
#
# ## Studi Kasus
# Sebuah e-commerce ingin menganalisis performa produk mereka.
#
# ## Data yang Diberikan
# ```python
# data_produk = [
#     {"id": "P001", "nama": "Laptop Gaming", "kategori": "Elektronik", "harga": 15000000, "stok": 10, "terjual": 45, "rating": 4.5},
#     {"id": "P002", "nama": "Mouse Wireless", "kategori": "Aksesoris", "harga": 200000, "stok": 50, "terjual": 120, "rating": 4.8},
#     {"id": "P003", "nama": "Keyboard Mechanical", "kategori": "Aksesoris", "harga": 800000, "stok": 30, "terjual": 85, "rating": 4.6},
#     {"id": "P004", "nama": "Monitor 4K", "kategori": "Elektronik", "harga": 5000000, "stok": 15, "terjual": 32, "rating": 4.7},
#     {"id": "P005", "nama": "Headset Gaming", "kategori": "Aksesoris", "harga": 1500000, "stok": 25, "terjual": 78, "rating": 4.4},
#     {"id": "P006", "nama": "Webcam HD", "kategori": "Aksesoris", "harga": 600000, "stok": 40, "terjual": 95, "rating": 4.3},
#     {"id": "P007", "nama": "SSD 1TB", "kategori": "Komponen", "harga": 2000000, "stok": 20, "terjual": 60, "rating": 4.9},
#     {"id": "P008", "nama": "RAM 16GB", "kategori": "Komponen", "harga": 1500000, "stok": 35, "terjual": 88, "rating": 4.5}
# ]
# ```
#
# ## Tugas (Opsional - Jika Ada Waktu)
#
# 1. Buat pure functions untuk:
#    - Menghitung revenue per produk (harga × terjual)
#    - Filter produk berdasarkan kategori
#    - Menghitung total revenue per kategori
#    - Mencari produk dengan rating tertinggi
#
# 2. Buat visualisasi:
#    - Bar chart: Revenue per kategori
#    - Scatter plot: Hubungan antara harga vs rating
#    - Pie chart: Distribusi stok per kategori
#
# **Gunakan semua teknik functional programming yang telah dipelajari!**

# %%
# Data yang diberikan (opsional)
data_produk = [
    {"id": "P001", "nama": "Laptop Gaming", "kategori": "Elektronik", "harga": 15000000, "stok": 10, "terjual": 45, "rating": 4.5},
    {"id": "P002", "nama": "Mouse Wireless", "kategori": "Aksesoris", "harga": 200000, "stok": 50, "terjual": 120, "rating": 4.8},
    {"id": "P003", "nama": "Keyboard Mechanical", "kategori": "Aksesoris", "harga": 800000, "stok": 30, "terjual": 85, "rating": 4.6},
    {"id": "P004", "nama": "Monitor 4K", "kategori": "Elektronik", "harga": 5000000, "stok": 15, "terjual": 32, "rating": 4.7},
    {"id": "P005", "nama": "Headset Gaming", "kategori": "Aksesoris", "harga": 1500000, "stok": 25, "terjual": 78, "rating": 4.4},
    {"id": "P006", "nama": "Webcam HD", "kategori": "Aksesoris", "harga": 600000, "stok": 40, "terjual": 95, "rating": 4.3},
    {"id": "P007", "nama": "SSD 1TB", "kategori": "Komponen", "harga": 2000000, "stok": 20, "terjual": 60, "rating": 4.9},
    {"id": "P008", "nama": "RAM 16GB", "kategori": "Komponen", "harga": 1500000, "stok": 35, "terjual": 88, "rating": 4.5}
]

# Tulis jawaban Anda di sini (opsional)

# %% [markdown]
# ---
#
# ## 📝 Catatan Penting
#
# 1. **Pastikan semua fungsi adalah pure functions** - tidak ada side effects
# 2. **Gunakan immutable update** - selalu buat data baru, jangan modifikasi yang lama
# 3. **Kombinasikan semua teknik** - list comprehension, map, filter, reduce, lambda, closure, generator expression
# 4. **Visualisasi harus informatif** - title, label, legend, grid, format angka
# 5. **Waktu terbatas** - fokus pada soal 1 dan 2, soal 3 opsional
#
# **Selamat mengerjakan! Semoga sukses di UAP! 🚀**
